# %%
# %load_ext watermark

# %%
# %watermark
# Out:
# Last updated: 2023-07-14T12:14:12.356660-06:00
#
# Python implementation: CPython
# Python version       : 3.10.11
# IPython version      : 8.12.0
#
# Compiler    : GCC 11.2.0
# OS          : Linux
# Release     : 6.2.0-24-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 6
# Architecture: 64bit

# %%
import pandas as pd

# %%
df = pd.read_csv("/home/carlostr/curso_data_science-master/Secciones/Seccion4.Analisis_y_procesado_de_datos/Visualización de datos en Python/boston_dataset.csv")

# %%
df.head()
# Out:
#          TOWN     LON      LAT  MEDV     CRIM    ZN  INDUS  CHAS    NOX  \
# 0      Nahant -70.955  42.2550  24.0  0.00632  18.0   2.31     0  0.538
# 1  Swampscott -70.950  42.2875  21.6  0.02731   0.0   7.07     0  0.469
# 2  Swampscott -70.936  42.2830  34.7  0.02729   0.0   7.07     0  0.469
# 3  Marblehead -70.928  42.2930  33.4  0.03237   0.0   2.18     0  0.458
# 4  Marblehead -70.922  42.2980  36.2  0.06905   0.0   2.18     0  0.458
#
#       RM   AGE     DIS  RAD  TAX  PTRATIO       B  LSTAT
# 0  6.575  65.2  4.0900    1  296     15.3  396.90   4.98
# 1  6.421  78.9  4.9671    2  242     17.8  396.90   9.14
# 2  7.185  61.1  4.9671    2  242     17.8  392.83   4.03
# 3  6.998  45.8  6.0622    3  222     18.7  394.63   2.94
# 4  7.147  54.2  6.0622    3  222     18.7  396.90   5.33

# %%
df = df.rename(columns= {
    "TOWN": "Ciudad",
    "CRIM": "Criminalidad",
    "ZN": "PCT_Zona_Residencial",
    "INDUS": "PCT_Zona_Industrial",
    "CHAS": "Rio_Charles",
    "NOX": "Oxido_Nitroso_PPM",
    "RM": "N_Habitaciones_Medio",
    "AGE": "PCT_Casas_405",
    "DIS": "Distancia_a_Empleo",
    "RAD": "Distancia_a_Autopistas",
    "TAX": "Carga_Fiscal",
    "PTRATIO":"Ratio_Profesores",
    "B": "PCT_Negra",
    "MEDV": "Valor_Mediano",
    "LSTAT": "PCT_Clase_Baja"
})

# %%
df.head()
# Out:
#        Ciudad     LON      LAT  Valor_Mediano  Criminalidad  \
# 0      Nahant -70.955  42.2550           24.0       0.00632
# 1  Swampscott -70.950  42.2875           21.6       0.02731
# 2  Swampscott -70.936  42.2830           34.7       0.02729
# 3  Marblehead -70.928  42.2930           33.4       0.03237
# 4  Marblehead -70.922  42.2980           36.2       0.06905
#
#    PCT_Zona_Residencial  PCT_Zona_Industrial  Rio_Charles  Oxido_Nitroso_PPM  \
# 0                  18.0                 2.31            0              0.538
# 1                   0.0                 7.07            0              0.469
# 2                   0.0                 7.07            0              0.469
# 3                   0.0                 2.18            0              0.458
# 4                   0.0                 2.18            0              0.458
#
#    N_Habitaciones_Medio  PCT_Casas_405  Distancia_a_Empleo  \
# 0                 6.575           65.2              4.0900
# ...

# %%
from IPython.display import Image #Modulo para importar una imagen

# %%
# Image("/home/carlostr/curso_data_science-master/Jupyter/chart-chooser.png")

# %%
"""
#Graficos de dispersion para comparar variables
import matplotlib.pyplot as plt
df.plot.scatter(x="Criminalidad",y="Valor_Mediano")
plt.show()
"""
# Out:
# '\n#Graficos de dispersion para comparar variables\nimport matplotlib.pyplot as plt\ndf.plot.scatter(x="Criminalidad",y="Valor_Mediano")\nplt.show()\n'

# %%
"""
#Esto es para avisarle al programa que estoy en jupyter y no tener que usar plt.show() cada vez
# %matplotlib notebook 
df.plot.scatter(x="Criminalidad",y="Valor_Mediano")
"""
# Out:
# '\n#Esto es para avisarle al programa que estoy en jupyter y no tener que usar plt.show() cada vez\n%matplotlib notebook \ndf.plot.scatter(x="Criminalidad",y="Valor_Mediano")\n'

# %%
from pandas.plotting import scatter_matrix
sm = scatter_matrix(df,alpha=0.2,diagonal='kde')

# %%
sm = scatter_matrix(df, alpha=0.2, figsize=(14, 14), diagonal='kde')

#https://stackoverflow.com/questions/32560932/how-to-customize-a-scatter-matrix-to-see-all-titles
#Change label rotation
[s.xaxis.label.set_rotation(45) for s in sm.reshape(-1)]
[s.yaxis.label.set_rotation(0) for s in sm.reshape(-1)]

#May need to offset label when rotating to prevent overlap of figure
[s.get_yaxis().set_label_coords(-1,0.5) for s in sm.reshape(-1)]
[s.get_xaxis().set_label_coords(-0.2,0) for s in sm.reshape(-1)]

#Hide all ticks
[s.set_xticks(()) for s in sm.reshape(-1)]
[s.set_yticks(()) for s in sm.reshape(-1)];

# %%
# %matplotlib inline 
#inline para graficos que no tenemos que editar 
df.Valor_Mediano.plot.kde() #Con esta funcion vemos la distribucion de la variable Valor_Mediano
# Out:
# <Axes: ylabel='Density'>

# %%
df.Valor_Mediano.plot.hist() #La misma distribucion pero con un histograma
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.Criminalidad.plot.hist()
df.Criminalidad.plot.hist(bins=20) #El argumento bins hace que el histograma se parta en mas cuadrados
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.Criminalidad.plot.hist(xlim=(0,25),color="red") #Rojo
df.Criminalidad.plot.hist(xlim=(0,25),bins=20) #Azul
# Out:
# <Axes: ylabel='Frequency'>

# %%
valor_por_ciudad = df.groupby("Ciudad")["Valor_Mediano"].mean() #Valor mediano por zona
valor_por_ciudad.head()
# Out:
# Ciudad
# Arlington    25.2
# Ashland      21.4
# Bedford      30.1
# Belmont      36.2
# Beverly      20.8
# Name: Valor_Mediano, dtype: float64

# %%
valor_por_ciudad.head(15).plot.bar() #Grafica de barras
# Out:
# <Axes: xlabel='Ciudad'>

# %%
valor_por_ciudad.head(15).plot.barh() #Grafica de barras horizontal
# Out:
# <Axes: ylabel='Ciudad'>

# %%
#Grafico de lineas: cuando tengas una tendencia temporal en los datos
df.groupby("Ratio_Profesores")["Valor_Mediano"].mean().plot.line()
# Out:
# <Axes: xlabel='Ratio_Profesores'>

# %%
df.Rio_Charles.value_counts() #Esta funcion cuenta los valores, en el caso del rio charles es 0 y 1 (Esta o no)
# Out:
# 0    471
# 1     35
# Name: Rio_Charles, dtype: int64

# %%
df.Rio_Charles.value_counts().plot.pie() #Una grafica de pastel
# Out:
# <Axes: ylabel='Rio_Charles'>

# %%
df.Rio_Charles.value_counts().plot.barh() #Con esta funcion se ve mejor qla diferencia
# Out:
# <Axes: >
