# %%
# %load_ext watermark
# %watermark
# Out:
# Last updated: 2023-08-14T13:30:02.612311-06:00
#
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 8.12.2
#
# Compiler    : GCC 11.2.0
# OS          : Linux
# Release     : 6.2.0-27-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 6
# Architecture: 64bit

# %% [markdown]
# Aquí incluyo unas herramientas que son bastante útiles a la hora de hacer EDA

# %% [markdown]
# ### Ingesta de datos

# %%
import pandas as pd

vehiculos = pd.read_csv("/home/carlostr/curso_data_science-master/Secciones/Seccion4.Analisis_y_procesado_de_datos/Procesado_de_Datos/data/vehiculos_original.csv")

# %% [markdown]
# ### Pandas-profiling
#
# https://github.com/JosPolfliet/pandas-profiling

# %%
# !conda install -y pandas-profiling
# Out:
# Collecting ydata-profiling
#   Obtaining dependency information for ydata-profiling from https://files.pythonhosted.org/packages/09/98/5a5fbfd48bf23acd3ceed5114d073b877965816304078151fefbf86d8458/ydata_profiling-4.5.1-py2.py3-none-any.whl.metadata
#   Downloading ydata_profiling-4.5.1-py2.py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: scipy<1.12,>=1.4.1 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from ydata-profiling) (1.10.1)
# Requirement already satisfied: pandas!=1.4.0,<2.1,>1.1 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from ydata-profiling) (1.5.3)
# Requirement already satisfied: matplotlib<4,>=3.2 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from ydata-profiling) (3.7.1)
# Collecting pydantic<2,>=1.8.1 (from ydata-profiling)
#   Obtaining dependency information for pydantic<2,>=1.8.1 from https://files.pythonhosted.org/packages/bc/e0/0371e9b6c910afe502e5fe18cc94562bfd9399617c7b4f5b6e13c29115b3/pydantic-1.10.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pydantic-1.10.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.3/149.3 kB 756.9 kB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from ydata-profiling) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from ydata-profiling) (3.1.2)
# Collecting visions[type_image_path]==0.7.5 (from ydata-profiling)
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 1.7 MB/s eta 0:00:00m eta 0:00:01
# Requirement already satisfied: numpy<1.24,>=1.16.0 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from ydata-profiling) (1.23.5)
# Requirement already satisfied: htmlmin==0.1.12 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from ydata-profiling) (0.12.3)
# Requirement already satisfied: requests<3,>=2.24.0 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from ydata-profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from ydata-profiling) (4.65.0)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from ydata-profiling) (0.12.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from ydata-profiling) (0.13.5)
# Collecting typeguard<3,>=2.13.2 (from ydata-profiling)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: imagehash==4.3.1 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from ydata-profiling) (4.3.1)
# Collecting wordcloud>=1.9.1 (from ydata-profiling)
#   Obtaining dependency information for wordcloud>=1.9.1 from https://files.pythonhosted.org/packages/22/0d/bb4eccd60d272b33cbc79c661c60acc604f1688cfc922deb9d3eb5be640a/wordcloud-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading wordcloud-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Obtaining dependency information for dacite>=1.8 from https://files.pythonhosted.org/packages/21/0f/cf0943f4f55f0fbc7c6bd60caf1343061dff818b02af5a0d444e473bb78d/dacite-1.8.1-py3-none-any.whl.metadata
#   Downloading dacite-1.8.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pillow in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from imagehash==4.3.1->ydata-profiling) (9.4.0)
# Requirement already satisfied: PyWavelets in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from imagehash==4.3.1->ydata-profiling) (1.4.1)
# Requirement already satisfied: attrs>=19.3.0 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling) (22.1.0)
# Requirement already satisfied: networkx>=2.4 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling) (3.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from pandas!=1.4.0,<2.1,>1.1->ydata-profiling) (2022.7)
# Requirement already satisfied: joblib>=0.14.1 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from pydantic<2,>=1.8.1->ydata-profiling) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2023.7.22)
# Requirement already satisfied: patsy>=0.5.2 in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.3)
# Requirement already satisfied: six in /home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# Downloading ydata_profiling-4.5.1-py2.py3-none-any.whl (357 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.3/357.3 kB 1.3 MB/s eta 0:00:001.6 MB/s eta 0:00:01
# Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Downloading pydantic-1.10.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 2.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading wordcloud-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (455 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.4/455.4 kB 2.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# Installing collected packages: typeguard, pydantic, multimethod, dacite, wordcloud, visions, ydata-profiling
#   Attempting uninstall: visions
#     Found existing installation: visions 0.5.0
#     Uninstalling visions-0.5.0:
#       Successfully uninstalled visions-0.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 2.9.0 requires visions[type_image_path]==0.5.0, but you have visions 0.7.5 which is incompatible.
# Successfully installed dacite-1.8.1 multimethod-1.9.1 pydantic-1.10.12 typeguard-2.13.3 visions-0.7.5 wordcloud-1.9.2 ydata-profiling-4.5.1

# %%
import pandas_profiling

pandas_profiling.ProfileReport(vehiculos)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas_profiling
#       3 pandas_profiling.ProfileReport(vehiculos)
#
# File ~/anaconda3/envs/data/lib/python3.10/site-packages/pandas_profiling/__init__.py:7
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
#       6 from pandas_profiling.config import Config, config
# ----> 7 from pandas_profiling.controller import pandas_decorator
#       8 from pandas_profiling.profile_report import ProfileReport
#       9 from pandas_profiling.version import __version__
#
# File ~/anaconda3/envs/data/lib/python3.10/site-packages/pandas_profiling/controller/pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.__init__ import ProfileReport
#       7 def profile_report(df, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
#      10     Args:
#    (...)
#      15         A ProfileReport of the DataFrame.
#      16     """
#
# File ~/anaconda3/envs/data/lib/python3.10/site-packages/pandas_profiling/__init__.py:8
#       6 from pandas_profiling.config import Config, config
#       7 from pandas_profiling.controller import pandas_decorator
# ----> 8 from pandas_profiling.profile_report import ProfileReport
#       9 from pandas_profiling.version import __version__
#      11 clear_config = ProfileReport.clear_config
#
# File ~/anaconda3/envs/data/lib/python3.10/site-packages/pandas_profiling/profile_report.py:11
#       8 from tqdm.auto import tqdm
#      10 from pandas_profiling.config import config
# ---> 11 from pandas_profiling.model.describe import describe as describe_df
#      12 from pandas_profiling.model.messages import MessageType
#      13 from pandas_profiling.report import get_report_structure
#
# File ~/anaconda3/envs/data/lib/python3.10/site-packages/pandas_profiling/model/describe.py:11
#       9 from pandas_profiling.config import config as config
#      10 from pandas_profiling.model.base import Variable
# ---> 11 from pandas_profiling.model.correlations import calculate_correlation
#      12 from pandas_profiling.model.sample import Sample, get_sample
#      13 from pandas_profiling.model.summary import (
#      14     get_duplicates,
#      15     get_messages,
#    (...)
#      19     get_table_stats,
#      20 )
#
# File ~/anaconda3/envs/data/lib/python3.10/site-packages/pandas_profiling/model/correlations.py:11
#       9 import pandas as pd
#      10 from confuse import NotFoundError
# ---> 11 from pandas.core.base import DataError
#      12 from scipy import stats
#      14 from pandas_profiling.config import config
#
# ImportError: cannot import name 'DataError' from 'pandas.core.base' (/home/carlostr/anaconda3/envs/data/lib/python3.10/site-packages/pandas/core/base.py)

# %%
# %matplotlib inline

# %% [markdown]
# ### Missigno
#
# https://github.com/ResidentMario/missingno

# %%
# !conda install -y missingno
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.5.0
#   latest version: 23.7.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.7.2
#
#
#
# # All requested packages already installed.

# %%
import missingno as msno

msno.matrix(vehiculos)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 import missingno as msno
# ----> 3 msno.matrix(vehiculos)
#
# File ~/anaconda3/envs/data/lib/python3.10/site-packages/missingno/missingno.py:72, in matrix(df, filter, n, p, sort, figsize, width_ratios, color, fontsize, labels, sparkline, inline, freq, ax)
#      70 # Remove extraneous default visual elements.
#      71 ax0.set_aspect('auto')
# ---> 72 ax0.grid(b=False)
#      73 ax0.xaxis.tick_top()
#      74 ax0.xaxis.set_ticks_position('none')
#
# File ~/anaconda3/envs/data/lib/python3.10/site-packages/matplotlib/axes/_base.py:3194, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3192 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3193 if axis in ['x', 'both']:
# -> 3194     self.xaxis.grid(visible, which=which, **kwargs)
#    3195 if axis in ['y', 'both']:
#    3196     self.yaxis.grid(visible, which=which, **kwargs)
#
# File ~/anaconda3/envs/data/lib/python3.10/site-packages/matplotlib/axis.py:1660, in Axis.grid(self, visible, which, **kwargs)
#    1657 if which in ['major', 'both']:
#    1658     gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1659                         if visible is None else visible)
# -> 1660     self.set_tick_params(which='major', **gridkw)
#    1661 self.stale = True
#
# File ~/anaconda3/envs/data/lib/python3.10/site-packages/matplotlib/axis.py:932, in Axis.set_tick_params(self, which, reset, **kwargs)
#     919 """
#     920 Set appearance parameters for ticks, ticklabels, and gridlines.
#     921
#    (...)
#     929     gridlines.
#     930 """
#     931 _api.check_in_list(['major', 'minor', 'both'], which=which)
# --> 932 kwtrans = self._translate_tick_params(kwargs)
#     934 # the kwargs are stored in self._major/minor_tick_kw so that any
#     935 # future new ticks will automatically get them
#     936 if reset:
#
# File ~/anaconda3/envs/data/lib/python3.10/site-packages/matplotlib/axis.py:1076, in Axis._translate_tick_params(kw, reverse)
#    1074 for key in kw_:
#    1075     if key not in allowed_keys:
# -> 1076         raise ValueError(
#    1077             "keyword %s is not recognized; valid keywords are %s"
#    1078             % (key, allowed_keys))
#    1079 kwtrans.update(kw_)
#    1080 return kwtrans
#
# ValueError: keyword grid_b is not recognized; valid keywords are ['size', 'width', 'color', 'tickdir', 'pad', 'labelsize', 'labelcolor', 'zorder', 'gridOn', 'tick1On', 'tick2On', 'label1On', 'label2On', 'length', 'direction', 'left', 'bottom', 'right', 'top', 'labelleft', 'labelbottom', 'labelright', 'labeltop', 'labelrotation', 'grid_agg_filter', 'grid_alpha', 'grid_animated', 'grid_antialiased', 'grid_clip_box', 'grid_clip_on', 'grid_clip_path', 'grid_color', 'grid_dash_capstyle', 'grid_dash_joinstyle', 'grid_dashes', 'grid_data', 'grid_drawstyle', 'grid_figure', 'grid_fillstyle', 'grid_gapcolor', 'grid_gid', 'grid_in_layout', 'grid_label', 'grid_linestyle', 'grid_linewidth', 'grid_marker', 'grid_markeredgecolor', 'grid_markeredgewidth', 'grid_markerfacecolor', 'grid_markerfacecoloralt', 'grid_markersize', 'grid_markevery', 'grid_mouseover', 'grid_path_effects', 'grid_picker', 'grid_pickradius', 'grid_rasterized', 'grid_sketch_params', 'grid_snap', 'grid_solid_capstyle', 'grid_solid_joinstyle', 'grid_transform', 'grid_url', 'grid_visible', 'grid_xdata', 'grid_ydata', 'grid_zorder', 'grid_aa', 'grid_c', 'grid_ds', 'grid_ls', 'grid_lw', 'grid_mec', 'grid_mew', 'grid_mfc', 'grid_mfcalt', 'grid_ms']

# %%
msno.heatmap(vehiculos)
# Out:
# <Axes: >
