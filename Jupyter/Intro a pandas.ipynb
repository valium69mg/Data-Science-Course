# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
#Creamos un data frame 
rick_and_morty = pd.DataFrame({
    "nombre" : ["Rick","Morty"],
    "apellido" : ["Sanchez","Smith"],
    "edad" : ["70","14"]
})
rick_and_morty
# Out:
#   nombre apellido edad
# 0   Rick  Sanchez   70
# 1  Morty    Smith   14

# %%
#Crear data frames con listas
rick_and_morty = pd.DataFrame(
    [["Rick","Sanchez","70"],
    ["Morty","Smith","14"]],
    columns = ["Nombre","Apellido","Edad"]
)
rick_and_morty
# Out:
#   Nombre Apellido Edad
# 0   Rick  Sanchez   70
# 1  Morty    Smith   14

# %%
# !head -n 5 /home/carlostr/curso_data_science-master/Secciones/Seccion3.Intro_a_Data_Science/Intro_a_Pandas/primary_results.csv
# Out:
# state,state_abbreviation,county,fips,party,candidate,votes,fraction_votes
# Alabama,AL,Autauga,1001.0,Democrat,Bernie Sanders,544,0.182
# Alabama,AL,Autauga,1001.0,Democrat,Hillary Clinton,2387,0.8
# Alabama,AL,Baldwin,1003.0,Democrat,Bernie Sanders,2694,0.32899999999999996
# Alabama,AL,Baldwin,1003.0,Democrat,Hillary Clinton,5290,0.647

# %%
votos = pd.read_csv("/home/carlostr/curso_data_science-master/Secciones/Seccion3.Intro_a_Data_Science/Intro_a_Pandas/primary_results.csv") 
votos
# Out:
#          state state_abbreviation          county        fips       party  \
# 0      Alabama                 AL         Autauga      1001.0    Democrat
# 1      Alabama                 AL         Autauga      1001.0    Democrat
# 2      Alabama                 AL         Baldwin      1003.0    Democrat
# 3      Alabama                 AL         Baldwin      1003.0    Democrat
# 4      Alabama                 AL         Barbour      1005.0    Democrat
# ...        ...                ...             ...         ...         ...
# 24606  Wyoming                 WY  Teton-Sublette  95600028.0  Republican
# 24607  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24608  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24609  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24610  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
#
#              candidate  votes  fraction_votes
# ...

# %%
df = votos #Si solo usamos un data frame se usa df para definirlo

# %%
#este comando nos muestra las primeras filas
df.head(3)
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329

# %%
#este comando nos muestra las ultimas filas
df.tail(3)
# Out:
#          state state_abbreviation         county        fips       party  \
# 24608  Wyoming                 WY  Uinta-Lincoln  95600027.0  Republican
# 24609  Wyoming                 WY  Uinta-Lincoln  95600027.0  Republican
# 24610  Wyoming                 WY  Uinta-Lincoln  95600027.0  Republican
#
#          candidate  votes  fraction_votes
# 24608  John Kasich      0             0.0
# 24609  Marco Rubio      0             0.0
# 24610     Ted Cruz     53             1.0

# %%
df.dtypes #Esta linea nos muestra los data types de la tabla
# Out:
# state                  object
# state_abbreviation     object
# county                 object
# fips                  float64
# party                  object
# candidate              object
# votes                   int64
# fraction_votes        float64
# dtype: object

# %%
df.describe()
# Out:
#                fips          votes  fraction_votes
# count  2.451100e+04   24611.000000    24611.000000
# mean   2.667152e+07    2306.252773        0.304524
# std    4.200978e+07    9861.183572        0.231401
# min    1.001000e+03       0.000000        0.000000
# 25%    2.109100e+04      68.000000        0.094000
# 50%    4.208100e+04     358.000000        0.273000
# 75%    9.090012e+07    1375.000000        0.479000
# max    9.560004e+07  590502.000000        1.000000

# %%
df.loc[1] #devuelve la segunda linea de la tabla
# Out:
# state                         Alabama
# state_abbreviation                 AL
# county                        Autauga
# fips                           1001.0
# party                        Democrat
# candidate             Hillary Clinton
# votes                            2387
# fraction_votes                    0.8
# Name: 1, dtype: object

# %%
df["state"] #Seleccionamos una columna
# Out:
# 0        Alabama
# 1        Alabama
# 2        Alabama
# 3        Alabama
# 4        Alabama
#           ...
# 24606    Wyoming
# 24607    Wyoming
# 24608    Wyoming
# 24609    Wyoming
# 24610    Wyoming
# Name: state, Length: 24611, dtype: object

# %%
df["i"] = 1 #Creamos una columna con el valor 1 
df.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes  i
# 0    544           0.182  1
# 1   2387           0.800  1
# 2   2694           0.329  1
# 3   5290           0.647  1
# 4    222           0.078  1

# %%
df[df.votes>200000] #Filtramos los candidatos con votos mayores a 200.000
# Out:
#               state state_abbreviation        county        fips     party  \
# 1385     California                 CA   Los Angeles      6037.0  Democrat
# 1386     California                 CA   Los Angeles      6037.0  Democrat
# 4450       Illinois                 IL       Chicago  91700103.0  Democrat
# 4451       Illinois                 IL       Chicago  91700103.0  Democrat
# 4462       Illinois                 IL  Cook Suburbs  91700104.0  Democrat
# 4463       Illinois                 IL  Cook Suburbs  91700104.0  Democrat
# 17309  Pennsylvania                 PA  Philadelphia     42101.0  Democrat
#
#              candidate   votes  fraction_votes  i
# 1385    Bernie Sanders  434656           0.420  1
# 1386   Hillary Clinton  590502           0.570  1
# 4450    Bernie Sanders  311225           0.454  1
# 4451   Hillary Clinton  366954           0.536  1
# 4462    Bernie Sanders  212428           0.457  1
# 4463   Hillary Clinton  249217           0.536  1
# ...

# %%
df[(df.county == "Chicago")&(df.votes>200000)] #Filtramos con dos condiciones
# Out:
#          state state_abbreviation   county        fips     party  \
# 4450  Illinois                 IL  Chicago  91700103.0  Democrat
# 4451  Illinois                 IL  Chicago  91700103.0  Democrat
#
#             candidate   votes  fraction_votes  i
# 4450   Bernie Sanders  311225           0.454  1
# 4451  Hillary Clinton  366954           0.536  1

# %%
county = "Chicago"
county_democrat = df.query("county==@county and party == 'Democrat'")
county_democrat #Filtramos por condado los votos democratas
# Out:
#          state state_abbreviation   county        fips     party  \
# 4450  Illinois                 IL  Chicago  91700103.0  Democrat
# 4451  Illinois                 IL  Chicago  91700103.0  Democrat
#
#             candidate   votes  fraction_votes  i
# 4450   Bernie Sanders  311225           0.454  1
# 4451  Hillary Clinton  366954           0.536  1

# %%
df.sort_values(by="votes", ascending=False) #Aqui ordenamos la tabla conforme a la cantidad de votos
# Out:
#               state state_abbreviation        county        fips     party  \
# 1386     California                 CA   Los Angeles      6037.0  Democrat
# 1385     California                 CA   Los Angeles      6037.0  Democrat
# 4451       Illinois                 IL       Chicago  91700103.0  Democrat
# 4450       Illinois                 IL       Chicago  91700103.0  Democrat
# 4463       Illinois                 IL  Cook Suburbs  91700104.0  Democrat
# ...             ...                ...           ...         ...       ...
# 8476          Maine                 ME     Greenbush  92300181.0  Democrat
# 8474          Maine                 ME    Great Pond  92300180.0  Democrat
# 8473          Maine                 ME    Great Pond  92300180.0  Democrat
# 9637  Massachusetts                 MA       Holland  92500135.0  Democrat
# 8290          Maine                 ME   Castle Hill  92300087.0  Democrat
#
#             candidate   votes  fraction_votes  i
# ...

# %%
df.groupby(["state","party"]).votes.sum() #Sumamos los votos por estado y por partido
# Out:
# state          party
# Alabama        Democrat       386327
#                Republican     837632
# Alaska         Democrat          539
#                Republican      21930
# Arizona        Democrat       399097
#                               ...
# West Virginia  Republican     188138
# Wisconsin      Democrat      1000703
#                Republican    1072699
# Wyoming        Democrat          280
#                Republican        903
# Name: votes, Length: 95, dtype: int64

# %%
df["letra_estado"] = df.state_abbreviation.apply(lambda x: x[0]) #Aqui le aplicamos una funcion a la columna de estado 
df #Aqui agregamos una columna con la letra del estado mediante una funcion lambda
# Out:
#          state state_abbreviation          county        fips       party  \
# 0      Alabama                 AL         Autauga      1001.0    Democrat
# 1      Alabama                 AL         Autauga      1001.0    Democrat
# 2      Alabama                 AL         Baldwin      1003.0    Democrat
# 3      Alabama                 AL         Baldwin      1003.0    Democrat
# 4      Alabama                 AL         Barbour      1005.0    Democrat
# ...        ...                ...             ...         ...         ...
# 24606  Wyoming                 WY  Teton-Sublette  95600028.0  Republican
# 24607  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24608  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24609  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24610  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
#
#              candidate  votes  fraction_votes  i letra_estado
# ...

# %%
df["i"] = 1 #creamos una columna 'i
df
# Out:
#          state state_abbreviation          county        fips       party  \
# 0      Alabama                 AL         Autauga      1001.0    Democrat
# 1      Alabama                 AL         Autauga      1001.0    Democrat
# 2      Alabama                 AL         Baldwin      1003.0    Democrat
# 3      Alabama                 AL         Baldwin      1003.0    Democrat
# 4      Alabama                 AL         Barbour      1005.0    Democrat
# ...        ...                ...             ...         ...         ...
# 24606  Wyoming                 WY  Teton-Sublette  95600028.0  Republican
# 24607  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24608  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24609  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24610  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
#
#              candidate  votes  fraction_votes letra_estado  i
# ...

# %%
df_pobreza = pd.read_csv("/home/carlostr/curso_data_science-master/Secciones/Seccion3.Intro_a_Data_Science/Intro_a_Pandas/PovertyEstimates.csv")
df_pobreza
# Out:
#       FIPStxt  PCTPOVALL_2015
# 0           0            14.7
# 1        1000            18.5
# 2        1001            12.7
# 3        1003            12.9
# 4        1005            32.0
# ...       ...             ...
# 3189    56037             8.5
# 3190    56039             6.6
# 3191    56041             9.8
# 3192    56043            11.2
# 3193    56045             9.8
#
# [3194 rows x 2 columns]

# %%
df_merged = df.merge(df_pobreza, left_on = 'fips',right_on = 'FIPStxt')
df_merged.head()
# Out:
#      state state_abbreviation   county    fips       party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0    Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0    Democrat  Hillary Clinton
# 2  Alabama                 AL  Autauga  1001.0  Republican       Ben Carson
# 3  Alabama                 AL  Autauga  1001.0  Republican     Donald Trump
# 4  Alabama                 AL  Autauga  1001.0  Republican      John Kasich
#
#    votes  fraction_votes letra_estado  FIPStxt  PCTPOVALL_2015
# 0    544           0.182            A     1001            12.7
# 1   2387           0.800            A     1001            12.7
# 2   1764           0.146            A     1001            12.7
# 3   5387           0.445            A     1001            12.7
# 4    421           0.035            A     1001            12.7
